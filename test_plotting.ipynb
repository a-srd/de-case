# %%
from src.data_processing.utils import get_competitors, get_last_five_years_data
# Out:
# /Users/anthonyrajecki-doyle/Documents/GitHub/de-case/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
get_last_five_years_data()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_last_five_years_data()
#
# File ~/Documents/GitHub/de-case/src/data_processing/utils.py:22, in get_last_five_years_data()
#      17 def get_last_five_years_data():
#      18     """
#      19     Returns data from the last five years. If the data is cached, it loads the data from the cache.
#      20     Otherwise, it fetches the data, caches it, and then returns it.
#      21     """
# ---> 22     cache_path = os.makedirs(api_cache_root,"last_five_years_data.csv").resolve()
#      24     if cache_path.exists():
#      25         print(api_cache_root)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/os.py:225, in makedirs(name, mode, exist_ok)
#     223         return
#     224 try:
# --> 225     mkdir(name, mode)
# ...

# %%
import pandas as pd
pd.read_csv('cached_data/api_extracts/last_five_years_data.csv')
# Out:
#          NCT Number                                        Study Title  \
# 0       NCT06289062  Neoadjuvant Chemotherapy Plus Camrelizumab for...
# 1       NCT03963362  The Pharmacokinetics of GLA5PR Tablet Accordin...
# 2       NCT05251662  Sintilimab Combined With GEMOX ± IBI305 (Bevac...
# 3       NCT04099862  Eus-giuded Biliary Drainage With Ec-lams vs ER...
# 4       NCT04908280  Study of Ruxolitinib Cream for the Treatment o...
# ...             ...                                                ...
# 172872  NCT05151887  The Impact of a Whole-food Animal-based Versus...
# 172873  NCT05735587  Blueberries, Inflammation, Motivation, and Phy...
# 172874  NCT05056987  Clinical Assessment of Two Daily Wear Reusable...
# 172875  NCT05835687  Loc3CAR: Locoregional Delivery of B7-H3-CAR T ...
# 172876  NCT05121987  Analgesic and Respiratory Outcomes in Patients...
#
#                                            Study URL Acronym  \
# ...
